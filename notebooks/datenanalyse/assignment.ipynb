# %% [markdown]
# # A brief assignment on data analysis

# %% [markdown]
# The file `data/produkt_rr_stunde_19950901_20251231_03987.txt` contains observations of the hourly precipitation sum at the famous  DWD climate station in Potsdam (column `R1`).
#
# Please answer the following questions about this dataset. Add a markdown subsection for each question and then add your Python code in a comprehensible way and clearly highlight the answers to the corresponding question.
#
# Once finished, export the notebook as an html file and send it to the e-Mail address that was provided to you before. **You have a maximum of 30 minutes after the end of the interview.**

# %% [markdown]
# ### Questions about...
#
# **Missing data**
#
# The time series contains gaps *and* nodata values. Convert it to a gapless time series in which each previous gap is explicitely represented by a `nan` value. *How many hourly precipitation values are missing in total?*
#
# **Data quality I**
#
# For three datetimes, the hourly precipitation sums are obviously spurious. *Which datetimes? Why are these values spurious*? Set them to `nan` before you proceed.
#
# **Aggregation**
#
# Create a DataFrame with daily precipitation sums. In case one day has more than 2 missing hours, it should receive NaN rather than the sum. *How many NaN-days end up in your daily series?*
#
# **Data quality II**
#
# There is another highly spurious fragment in the hourly `R1` series. *Which?* Hint: Looking at individual hourly values is not enough.
#
# Fix this spurious fragment and recompute the daily series before you continue.
#
# **Range**
#
# *Which is the maximum daily precipiation sum in the entire time series and on which date did it occur? Are you familiar with what happened around this date?*
